# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.sparse
from lightfm import LightFM
from tqdm.auto import tqdm

from recommender.testing.custom_metric_utils import calculate_metric_scores
from recommender.testing.custom_metric_utils import create_recommendations_profiles_embeddings
from recommender.tools.lightfm_utils import LightFMTests

# %%
DATA_ROOT = '../../data'
THREADS = 8

# %% [markdown]
# ## Data loading

# %%
full_df = pd.read_csv(f'{DATA_ROOT}/ratings_all_implicit.csv.gz')
train_df = pd.read_csv(f'{DATA_ROOT}/ratings_train_implicit.csv.gz')
games_df = pd.read_json(f'{DATA_ROOT}/bgg_GameItem.jl', lines=True)[[
    'name', 'bgg_id', 'mechanic', 'category', 'complexity',
    'max_players_best', 'min_players_best', 'max_players_rec', 'min_players_rec'
]]

features_names = pd.read_csv(f'{DATA_ROOT}/game_features_names.csv.gz').values.flatten()
game_features = pd.read_csv(f'{DATA_ROOT}/game_features.csv.gz')

dataset = pd.read_pickle(f'{DATA_ROOT}/dataset.pkl')
item_features = pd.read_pickle(f'{DATA_ROOT}/item_features.pkl')

train_interactions = scipy.sparse.load_npz(f'{DATA_ROOT}/train_interactions.npz')
test_interactions = scipy.sparse.load_npz(f'{DATA_ROOT}/test_interactions.npz')

# %%
users_profiles = pd.read_pickle(f'{DATA_ROOT}/users_profiles.pkl')
test_users_profiles = pd.read_pickle(f'{DATA_ROOT}/test_users_profiles.pkl')
games_profiles = pd.read_pickle(f'{DATA_ROOT}/games_profiles.pkl')

# %% [markdown]
# ## Data processing

# %%
mechanics_names = features_names[:20]
categories_names = features_names[20:40]

# %%
users_profiles.index = users_profiles.index.map(dataset.mapping()[0])
test_users_profiles.index = test_users_profiles.index.map(dataset.mapping()[0])
games_profiles.index = games_profiles.index.map(dataset.mapping()[2])
users_profiles = users_profiles.sort_index()
test_users_profiles = test_users_profiles.sort_index()
games_profiles = games_profiles.sort_index()

# %%
users_profiles.values[:, :40] *= 3
test_users_profiles.values[:, :40] *= 3

# %%
cython_users_profiles = np.ascontiguousarray(users_profiles.values, dtype=np.float32)
cython_games_profiles = np.ascontiguousarray(games_profiles.values, dtype=np.float32)

# %%
users_profiles
# Out:
#                Card Game:1002  Children's Game:1041  Wargame:1019  \
# bgg_user_name
# 0                    0.185567              0.000000      0.463918
# 1                    0.750000              0.000000      0.300000
# 2                    0.588106              0.019824      0.218062
# 3                    0.900000              0.000000      0.300000
# 4                    0.512953              0.031088      0.481865
# ...                       ...                   ...           ...
# 255145               0.315789              0.078947      0.078947
# 255146               0.731707              0.073171      0.000000
# 255147               0.613043              0.013043      0.039130
# 255148               0.300000              0.000000      0.000000
# 255149               1.333333              0.000000      0.000000
#
#                Party Game:1030  Dice:1017  Abstract Strategy:1009  \
# bgg_user_name
# 0                     0.092784   0.030928                0.030928
# 1                     0.150000   0.300000                0.150000
# 2                     0.158590   0.118943                0.052863
# 3                     0.300000   0.000000                0.300000
# 4                     0.170984   0.062176                0.077720
# ...                        ...        ...                     ...
# 255145                0.157895   0.078947                0.078947
# 255146                0.219512   0.073171                0.000000
# 255147                0.273913   0.182609                0.104348
# 255148                0.300000   0.000000                0.000000
# 255149                0.000000   0.000000                0.666667
#
#                Educational:1094  Fantasy:1010  Trivia:1027  Print & Play:1120  \
# bgg_user_name
# 0                      0.000000      0.587629     0.092784           0.000000
# 1                      0.000000      0.750000     0.000000           0.000000
# 2                      0.019824      0.383260     0.019824           0.026432
# 3                      0.000000      0.000000     0.000000           0.000000
# 4                      0.031088      0.388601     0.015544           0.000000
# ...                         ...           ...          ...                ...
# 255145                 0.000000      0.315789     0.000000           0.000000
# 255146                 0.073171      0.219512     0.000000           0.000000
# 255147                 0.000000      0.234783     0.039130           0.052174
# 255148                 0.000000      0.600000     0.300000           0.000000
# 255149                 0.000000      0.000000     0.000000           0.000000
#
#                ...  Complexity: 2.75  Complexity: 3.0  Complexity: 3.25  \
# bgg_user_name  ...
# 0              ...          0.853234         0.719884          0.559403
# 1              ...          0.483044         0.249050          0.138632
# 2              ...          0.868630         0.743872          0.607954
# 3              ...          0.593081         0.391888          0.211645
# 4              ...          0.990435         0.934503          0.804351
# ...            ...               ...              ...               ...
# 255145         ...          0.747608         0.907259          1.000000
# 255146         ...          0.956630         0.852300          0.680646
# 255147         ...          0.852718         0.753342          0.621258
# 255148         ...          0.722659         0.524156          0.375908
# 255149         ...          0.208520         0.115428          0.064712
#
#                Complexity: 3.5  Complexity: 3.75  Complexity: 4.0  \
# bgg_user_name
# 0                     0.406612          0.257378         0.145929
# 1                     0.090537          0.061403         0.032269
# 2                     0.476589          0.346595         0.222867
# 3                     0.112041          0.036678         0.004190
# 4                     0.653234          0.457367         0.275569
# ...                        ...               ...              ...
# 255145                0.933529          0.798113         0.511489
# 255146                0.470204          0.321035         0.193476
# 255147                0.499052          0.390478         0.284043
# 255148                0.318827          0.224668         0.131764
# 255149                0.013997          0.000000         0.000000
#
#                Complexity: 4.25  Complexity: 4.5  Complexity: 4.75  \
# bgg_user_name
# 0                      0.067505         0.018451          0.004133
# 1                      0.003135         0.000000          0.000000
# 2                      0.122381         0.054664          0.016911
# 3                      0.000000         0.000000          0.000000
# 4                      0.145674         0.058051          0.026715
# ...                         ...              ...               ...
# 255145                 0.261847         0.113695          0.011540
# 255146                 0.123478         0.066910          0.032190
# 255147                 0.203207         0.132108          0.077190
# 255148                 0.074684         0.017604          0.000000
# 255149                 0.000000         0.000000          0.000000
#
#                Complexity: 5.0
# bgg_user_name
# 0                     0.000000
# 1                     0.000000
# 2                     0.003608
# 3                     0.000000
# 4                     0.013000
# ...                        ...
# 255145                0.000000
# 255146                0.016567
# 255147                0.038711
# 255148                0.000000
# 255149                0.000000
#
# [255150 rows x 71 columns]

# %% [markdown]
# ## Training & evaluating

# %%
PARAMS = {'no_components': 70,
          'learning_schedule': 'adadelta',
          'loss': 'warp',
          'item_alpha': 3e-06,
          'max_sampled': 10,
          'rho': 0.95,
          'epsilon': 1.0e-06,
          'random_state': 42}

model = LightFM(**PARAMS)

random.seed(42)
np.random.seed(42)

random_users_id = np.random.choice(test_users_profiles.index.values, size=2000, replace=False)
random_users_id.sort()

train_metrics_vals = []
test_metrics_vals = []
train_precision_vals = []
precision_vals = []
best_value = 0.0
best_epoch = 0
best_metric_value = 0.0
best_metric_epoch = 0
for i in tqdm(range(150)):
    model.fit_partial(train_interactions, verbose=False, item_features=item_features, epochs=2,
                      num_threads=THREADS, user_profiles=None, item_profiles=None)
    test_class = LightFMTests(model, train_df, dataset, train_interactions, test_interactions, item_features)
    num_recs = 5
    print("Creating recommendation profiles")
    recommendation_profiles = create_recommendations_profiles_embeddings(
        test_class.get_top_n(num_recs, random_users_id), num_recs, games_df, categories_names, mechanics_names, 10)
    recommendation_profiles.index = recommendation_profiles.index.map(dataset.mapping()[0])
    recommendation_profiles = recommendation_profiles.sort_index()
    train_metric = calculate_metric_scores(recommendation_profiles, users_profiles.loc[random_users_id])
    train_metrics_vals.append(train_metric)
    print("Train custom metric: ", train_metric)
    test_metric = calculate_metric_scores(recommendation_profiles, test_users_profiles.loc[random_users_id])
    test_metrics_vals.append(test_metric)
    print("Test custom metric: ", test_metric)
    train_precision = test_class.train_precision_at_k()
    train_precision_vals.append(train_precision)
    print("Train precision: ", train_precision)
    precision = test_class.precision_at_k()
    precision_vals.append(precision)
    if precision > best_value:
        best_value = precision
        best_epoch = (i+1)*2
    if test_metric[-1] > best_metric_value:
        best_metric_value = test_metric[-1]
        best_metric_epoch = (i+1)*2
    print("Test precision: ", precision)
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Creating recommendation profiles
# Train custom metric:  [0.53343454 0.80196807 0.29926791 0.76412034 2.39879086]
# Test custom metric:  [0.53524661 0.81090828 0.30134403 0.77433863 2.42183756]
# Train precision:  0.47545913
# Test precision:  0.24807754
# Creating recommendation profiles
# Train custom metric:  [0.59486579 0.82305605 0.30483907 0.76378788 2.48654879]
# Test custom metric:  [0.59165601 0.82862893 0.30605729 0.77455114 2.50089338]
# Train precision:  0.5086577
# Test precision:  0.25903088
# Creating recommendation profiles
# Train custom metric:  [0.6460463  0.85588281 0.3066861  0.77375457 2.58236979]
# Test custom metric:  [0.64218695 0.85736935 0.30756368 0.78320065 2.59032063]
# Train precision:  0.528214
# Test precision:  0.26257136
# Creating recommendation profiles
# Train custom metric:  [0.69626917 0.8080075  0.29899863 0.76979979 2.57307509]
# Test custom metric:  [0.69017237 0.80893976 0.29963518 0.7788908  2.57763812]
# Train precision:  0.54148227
# Test precision:  0.26493347
# Creating recommendation profiles
# Train custom metric:  [0.67669775 0.84375654 0.30539403 0.7677148  2.59356312]
# Test custom metric:  [0.67036226 0.8441459  0.30622483 0.77723918 2.59797217]
# Train precision:  0.5521843
# Test precision:  0.26915592
# Creating recommendation profiles
# Train custom metric:  [0.68658387 0.83150671 0.31069223 0.77846331 2.60724611]
# Test custom metric:  [0.67892072 0.83006037 0.31111165 0.78770849 2.60780123]
# Train precision:  0.55901474
# Test precision:  0.26931792
# Creating recommendation profiles
# Train custom metric:  [0.67615248 0.82484867 0.3097784  0.77512771 2.58590725]
# Test custom metric:  [0.66774923 0.82245054 0.31003666 0.78435595 2.58459238]
# Train precision:  0.5660482
# Test precision:  0.27002865
# Creating recommendation profiles
# Train custom metric:  [0.67516174 0.85387511 0.31143131 0.77422145 2.61468961]
# Test custom metric:  [0.66719349 0.85080566 0.31155639 0.78311351 2.61266905]
# Train precision:  0.5708415
# Test precision:  0.2711757
# Creating recommendation profiles
# Train custom metric:  [0.6862459  0.82360007 0.30996577 0.77819424 2.59800597]
# Test custom metric:  [0.67844688 0.82193628 0.31037804 0.78683792 2.59759912]
# Train precision:  0.5736265
# Test precision:  0.27307528
# Creating recommendation profiles
# Train custom metric:  [0.6687266  0.83091561 0.31179021 0.77827021 2.58970264]
# Test custom metric:  [0.66050264 0.82843808 0.31194988 0.78683989 2.58773048]
# Train precision:  0.57684726
# Test precision:  0.27403682
# Creating recommendation profiles
# Train custom metric:  [0.67576716 0.86164489 0.31327163 0.77570571 2.6263894 ]
# Test custom metric:  [0.66725326 0.85816087 0.31366151 0.78456749 2.62364313]
# Train precision:  0.5798581
# Test precision:  0.2727356
# Creating recommendation profiles
# Train custom metric:  [0.70339348 0.83696479 0.313607   0.77954168 2.63350695]
# Test custom metric:  [0.69477787 0.83429377 0.31389187 0.7880694  2.63103291]
# Train precision:  0.5841457
# Test precision:  0.27381995
# Creating recommendation profiles
# Train custom metric:  [0.6955846  0.83949767 0.31708859 0.77035485 2.62252571]
# Test custom metric:  [0.68662078 0.83621348 0.31695998 0.7790472  2.61884144]
# Train precision:  0.58515614
# Test precision:  0.27263892
# Creating recommendation profiles
# Train custom metric:  [0.66709822 0.81868143 0.31151937 0.77414724 2.57144626]
# Test custom metric:  [0.65953309 0.81717954 0.31178008 0.78303599 2.57152871]
# Train precision:  0.5860906
# Test precision:  0.27574044
# Creating recommendation profiles
# Train custom metric:  [0.65568198 0.82670872 0.31072327 0.7765931  2.56970707]
# Test custom metric:  [0.64730544 0.82447015 0.31079297 0.78534551 2.56791408]
# Train precision:  0.58686495
# Test precision:  0.27468222
# Creating recommendation profiles
# Train custom metric:  [0.69741648 0.83313342 0.30881456 0.77007944 2.6094439 ]
# Test custom metric:  [0.68941853 0.82969374 0.30893364 0.77908433 2.60713024]
# Train precision:  0.5922916
# Test precision:  0.27707562
# Creating recommendation profiles
# Train custom metric:  [0.68678185 0.81224966 0.30504922 0.77421404 2.57829477]
# Test custom metric:  [0.67811416 0.80815197 0.30510215 0.78286558 2.57423387]
# Train precision:  0.59253997
# Test precision:  0.27507675
# Creating recommendation profiles
# Train custom metric:  [0.67209497 0.83230428 0.31117325 0.77494181 2.5905143 ]
# Test custom metric:  [0.66411931 0.82935972 0.31159283 0.78394564 2.5890175 ]
# Train precision:  0.59531647
# Test precision:  0.27861464
# Creating recommendation profiles
# Train custom metric:  [0.68083007 0.83605842 0.31028805 0.77471393 2.60189048]
# Test custom metric:  [0.6730091  0.83305451 0.31014873 0.78398146 2.6001938 ]
# Train precision:  0.5957264
# Test precision:  0.27929664
# Creating recommendation profiles
# Train custom metric:  [0.6556901  0.83044041 0.3129679  0.77635936 2.57545777]
# Test custom metric:  [0.64855599 0.82860555 0.31330998 0.78557944 2.57605096]
# Train precision:  0.5951839
# Test precision:  0.278079
# Creating recommendation profiles
# Train custom metric:  [0.68836525 0.83084609 0.31031091 0.77108065 2.60060292]
# Test custom metric:  [0.68023394 0.82858619 0.31025401 0.77995047 2.5990246 ]
# Train precision:  0.5966263
# Test precision:  0.27715144
# Creating recommendation profiles
# Train custom metric:  [0.68774424 0.8397218  0.31474703 0.77655217 2.61876525]
# Test custom metric:  [0.67980622 0.83676725 0.3149392  0.78537828 2.61689094]
# Train precision:  0.60026336
# Test precision:  0.2773892
# Creating recommendation profiles
# Train custom metric:  [0.65679665 0.841113   0.31286996 0.77763086 2.58841046]
# Test custom metric:  [0.64953425 0.83832087 0.31332705 0.78660941 2.58779157]
# Train precision:  0.5998809
# Test precision:  0.2773787
# Creating recommendation profiles
# Train custom metric:  [0.69163042 0.85649318 0.31046007 0.77640454 2.63498822]
# Test custom metric:  [0.68277943 0.85400156 0.310761   0.78509508 2.63263707]
# Train precision:  0.6009578
# Test precision:  0.2776975
# Creating recommendation profiles
# Train custom metric:  [0.69342894 0.82521813 0.31397764 0.77387464 2.60649935]
# Test custom metric:  [0.68510089 0.82217943 0.3134648  0.78217857 2.6029237 ]
# Train precision:  0.6047682
# Test precision:  0.277478
# Creating recommendation profiles
# Train custom metric:  [0.69834415 0.82304139 0.31304628 0.77825326 2.61268507]
# Test custom metric:  [0.69037312 0.82019122 0.31284149 0.78698762 2.61039345]
# Train precision:  0.60558426
# Test precision:  0.27780467
# Creating recommendation profiles
# Train custom metric:  [0.67051718 0.85338587 0.31603105 0.77436049 2.61429459]
# Test custom metric:  [0.6633009  0.85180978 0.31603186 0.78356674 2.61470928]
# Train precision:  0.60554576
# Test precision:  0.27973038
# Creating recommendation profiles
# Train custom metric:  [0.69126603 0.84581481 0.31245678 0.77337812 2.62291574]
# Test custom metric:  [0.68416888 0.84293921 0.31244482 0.78212411 2.62167703]
# Train precision:  0.60560143
# Test precision:  0.28100285
# Creating recommendation profiles
# Train custom metric:  [0.69269755 0.84713828 0.31452365 0.77262347 2.62698294]
# Test custom metric:  [0.68500054 0.84529653 0.31462333 0.78070207 2.62562246]
# Train precision:  0.60760266
# Test precision:  0.27940634
# Creating recommendation profiles
# Train custom metric:  [0.69171982 0.82325215 0.31112874 0.77661156 2.60271227]
# Test custom metric:  [0.68385918 0.82023126 0.31106742 0.78502394 2.6001818 ]
# Train precision:  0.60748345
# Test precision:  0.27795884
# Creating recommendation profiles
# Train custom metric:  [0.65938503 0.84565471 0.31366831 0.77525648 2.59396452]
# Test custom metric:  [0.65294529 0.84327252 0.31382337 0.78330606 2.59334724]
# Train precision:  0.60838175
# Test precision:  0.27914765
# Creating recommendation profiles
# Train custom metric:  [0.68737931 0.87465182 0.31920851 0.77470319 2.65594283]
# Test custom metric:  [0.67960328 0.87196567 0.31892304 0.78330105 2.65379305]
# Train precision:  0.6101384
# Test precision:  0.27982444
# Creating recommendation profiles
# Train custom metric:  [0.66773144 0.82531633 0.31210629 0.77640683 2.58156089]
# Test custom metric:  [0.65964727 0.82285783 0.31219818 0.78481149 2.57951477]
# Train precision:  0.6098813
# Test precision:  0.27954748
# Creating recommendation profiles
# Train custom metric:  [0.68874869 0.83508097 0.31468139 0.77029456 2.60880561]
# Test custom metric:  [0.6814028  0.83321112 0.31447353 0.7787035  2.60779094]
# Train precision:  0.61089325
# Test precision:  0.28110474
# Creating recommendation profiles
# Train custom metric:  [0.69349905 0.83452432 0.31452192 0.77202674 2.61457203]
# Test custom metric:  [0.68512759 0.83292231 0.31422861 0.78123229 2.6135108 ]
# Train precision:  0.6112138
# Test precision:  0.28056648
# Creating recommendation profiles
# Train custom metric:  [0.71238724 0.81893939 0.31261032 0.77712855 2.62106551]
# Test custom metric:  [0.70418457 0.81672699 0.31243841 0.78498884 2.61833882]
# Train precision:  0.61407644
# Test precision:  0.27699986
# Creating recommendation profiles
# Train custom metric:  [0.67024608 0.83943759 0.31868965 0.77447251 2.60284584]
# Test custom metric:  [0.6635486  0.83819594 0.31875125 0.78298309 2.60347889]
# Train precision:  0.6127235
# Test precision:  0.28006482
# Creating recommendation profiles
# Train custom metric:  [0.68506575 0.83334876 0.31614131 0.77137455 2.60593037]
# Test custom metric:  [0.67645078 0.83040344 0.3160188  0.77928429 2.60215732]
# Train precision:  0.6163527
# Test precision:  0.27893868
# Creating recommendation profiles
# Train custom metric:  [0.69128416 0.83744379 0.31470427 0.77813065 2.62156287]
# Test custom metric:  [0.68278836 0.83505339 0.31443472 0.78651886 2.61879533]
# Train precision:  0.616203
# Test precision:  0.27914247
# Creating recommendation profiles
# Train custom metric:  [0.67486826 0.84238838 0.31279731 0.77478253 2.60483648]
# Test custom metric:  [0.66758157 0.83988609 0.31244269 0.7834119  2.60332225]
# Train precision:  0.61548495
# Test precision:  0.28008837
# Creating recommendation profiles
# Train custom metric:  [0.70272012 0.84721962 0.31711805 0.77042001 2.63747779]
# Test custom metric:  [0.69353821 0.84509831 0.31697204 0.77834032 2.63394888]
# Train precision:  0.6170731
# Test precision:  0.27915552
# Creating recommendation profiles
# Train custom metric:  [0.68244746 0.83567461 0.31062293 0.7777219  2.6064669 ]
# Test custom metric:  [0.67347322 0.83379292 0.3101415  0.78633284 2.60374047]
# Train precision:  0.6153603
# Test precision:  0.27969116
# Creating recommendation profiles
# Train custom metric:  [0.67881864 0.80836383 0.3117473  0.77848802 2.57741779]
# Test custom metric:  [0.67071399 0.80761482 0.31185598 0.78695449 2.57713928]
# Train precision:  0.615017
# Test precision:  0.27936193
# Creating recommendation profiles
# Train custom metric:  [0.65122408 0.86509348 0.31160924 0.7755826  2.60350941]
# Test custom metric:  [0.64435209 0.86300842 0.31157406 0.78445526 2.60338983]
# Train precision:  0.61644924
# Test precision:  0.28027645
# Creating recommendation profiles
# Train custom metric:  [0.67743974 0.83613337 0.31128034 0.77748149 2.60233495]
# Test custom metric:  [0.66823785 0.83385211 0.31103894 0.78558247 2.59871136]
# Train precision:  0.6187059
# Test precision:  0.2782619
# Creating recommendation profiles
# Train custom metric:  [0.71485609 0.83037493 0.31503132 0.77643054 2.63669288]
# Test custom metric:  [0.70515937 0.82786858 0.31490507 0.78479789 2.63273091]
# Train precision:  0.62218773
# Test precision:  0.27803457
# Creating recommendation profiles
# Train custom metric:  [0.67291656 0.83443956 0.31610168 0.77591095 2.59936875]
# Test custom metric:  [0.66417349 0.83224567 0.31584715 0.7837515  2.59601781]
# Train precision:  0.6196536
# Test precision:  0.28051162
# Creating recommendation profiles
# Train custom metric:  [0.71276898 0.81922235 0.31188616 0.77628961 2.62016709]
# Test custom metric:  [0.70374649 0.81736762 0.31171137 0.78419595 2.61702143]
# Train precision:  0.62242377
# Test precision:  0.27945343
# Creating recommendation profiles
# Train custom metric:  [0.66084518 0.81590953 0.31322279 0.77583846 2.56581595]
# Test custom metric:  [0.65241607 0.81454096 0.31329095 0.78438093 2.56462891]
# Train precision:  0.6196206
# Test precision:  0.28108382
# Creating recommendation profiles
# Train custom metric:  [0.66087647 0.83950587 0.31476203 0.77852058 2.59366495]
# Test custom metric:  [0.6526405  0.83802968 0.31456833 0.78673349 2.591972  ]
# Train precision:  0.6177206
# Test precision:  0.28072068
# Creating recommendation profiles
# Train custom metric:  [0.6888285  0.80655038 0.30973641 0.77399683 2.57911212]
# Test custom metric:  [0.68004415 0.80467068 0.30967584 0.78217168 2.57656236]
# Train precision:  0.62166953
# Test precision:  0.27995768
# Creating recommendation profiles
# Train custom metric:  [0.67423507 0.80227153 0.31296984 0.77470034 2.56417678]
# Test custom metric:  [0.66628705 0.8009933  0.31325718 0.78254369 2.56308123]
# Train precision:  0.6207706
# Test precision:  0.2797251
# Creating recommendation profiles
# Train custom metric:  [0.6650436  0.82566024 0.31572899 0.77605246 2.58248529]
# Test custom metric:  [0.65568307 0.82420962 0.31562057 0.78371253 2.57922579]
# Train precision:  0.6215073
# Test precision:  0.27959973
# Creating recommendation profiles
# Train custom metric:  [0.69853162 0.83699736 0.31665866 0.77479726 2.62698491]
# Test custom metric:  [0.68895524 0.83496374 0.31673169 0.78290544 2.62355611]
# Train precision:  0.6250778
# Test precision:  0.28051946
# Creating recommendation profiles
# Train custom metric:  [0.70278557 0.80404551 0.31363693 0.77207715 2.59254515]
# Test custom metric:  [0.69321005 0.80293279 0.31332155 0.7794076  2.58887199]
# Train precision:  0.62516165
# Test precision:  0.28043324
# Creating recommendation profiles
# Train custom metric:  [0.69499693 0.82812823 0.31550633 0.77974691 2.61837839]
# Test custom metric:  [0.68590815 0.82608041 0.31576942 0.78729675 2.61505474]
# Train precision:  0.6254604
# Test precision:  0.27855194
# Creating recommendation profiles
# Train custom metric:  [0.69560368 0.84358921 0.31547078 0.77624804 2.6309117 ]
# Test custom metric:  [0.68731598 0.84214986 0.31533421 0.78422276 2.6290228 ]
# Train precision:  0.6258617
# Test precision:  0.2791294
# Creating recommendation profiles
# Train custom metric:  [0.7128034  0.84717113 0.31709179 0.77676649 2.65383282]
# Test custom metric:  [0.70379626 0.84614162 0.3169583  0.78423398 2.65113015]
# Train precision:  0.6277634
# Test precision:  0.28042278
# Creating recommendation profiles
# Train custom metric:  [0.69170664 0.83182549 0.31596593 0.77417345 2.6136715 ]
# Test custom metric:  [0.68308972 0.82987979 0.31581386 0.78242533 2.6112087 ]
# Train precision:  0.62639076
# Test precision:  0.27988714
# Creating recommendation profiles
# Train custom metric:  [0.6770504  0.80983547 0.31539644 0.77563726 2.57791956]
# Test custom metric:  [0.66791815 0.8083817  0.31523684 0.78321165 2.57474835]
# Train precision:  0.62754464
# Test precision:  0.28086174
# Creating recommendation profiles
# Train custom metric:  [0.68951386 0.84307885 0.3158242  0.77220354 2.62062045]
# Test custom metric:  [0.68091295 0.84229612 0.31574193 0.78026819 2.61921919]
# Train precision:  0.6279874
# Test precision:  0.2801014
# Creating recommendation profiles
# Train custom metric:  [0.68641327 0.80203893 0.31416747 0.7721859  2.57480558]
# Test custom metric:  [0.67783882 0.80097821 0.31425568 0.77987983 2.57295254]
# Train precision:  0.6268367
# Test precision:  0.27926525
# Creating recommendation profiles
# Train custom metric:  [0.7114837  0.80839801 0.31359209 0.77223858 2.60571239]
# Test custom metric:  [0.70225066 0.80712408 0.31363694 0.78012808 2.60313976]
# Train precision:  0.6310359
# Test precision:  0.28024507
# Creating recommendation profiles
# Train custom metric:  [0.70206227 0.83225672 0.31261204 0.77607637 2.62300739]
# Test custom metric:  [0.69386641 0.83139274 0.31249999 0.78421377 2.62197291]
# Train precision:  0.62977237
# Test precision:  0.27983224
# Creating recommendation profiles
# Train custom metric:  [0.6824567  0.82359757 0.31143884 0.77392602 2.59141913]
# Test custom metric:  [0.67377993 0.82295207 0.31135954 0.78121959 2.58931113]
# Train precision:  0.6290911
# Test precision:  0.27644596
# Creating recommendation profiles
# Train custom metric:  [0.70307117 0.83214762 0.31813563 0.77318551 2.62653994]
# Test custom metric:  [0.69534948 0.83179197 0.31812859 0.78137341 2.62664346]
# Train precision:  0.6306885
# Test precision:  0.27929926
# Creating recommendation profiles
# Train custom metric:  [0.70405604 0.82044764 0.31673203 0.77483346 2.61606917]
# Test custom metric:  [0.69675665 0.8205649  0.31643326 0.78273498 2.61648978]
# Train precision:  0.6309716
# Test precision:  0.28059262
# Creating recommendation profiles
# Train custom metric:  [0.70187658 0.80842076 0.31330989 0.77590124 2.59950846]
# Test custom metric:  [0.69356789 0.80737238 0.31352375 0.78371526 2.59817929]
# Train precision:  0.6307193
# Test precision:  0.28067362
# Creating recommendation profiles
# Train custom metric:  [0.66051033 0.83028313 0.31397415 0.7758903  2.58065791]
# Test custom metric:  [0.6529583  0.82965595 0.31391735 0.78377566 2.58030725]
# Train precision:  0.6279615
# Test precision:  0.28022942
# Creating recommendation profiles
# Train custom metric:  [0.68434385 0.80889735 0.3126619  0.76958077 2.57548387]
# Test custom metric:  [0.67637464 0.80782973 0.31298867 0.77726491 2.57445795]
# Train precision:  0.63035005
# Test precision:  0.28087744
# Creating recommendation profiles
# Train custom metric:  [0.6769076  0.83506548 0.32033325 0.77427714 2.60658346]
# Test custom metric:  [0.66922474 0.83462176 0.32030881 0.78197005 2.60612536]
# Train precision:  0.63225013
# Test precision:  0.27741268
# Creating recommendation profiles
# Train custom metric:  [0.68275296 0.83178072 0.31576347 0.7739157  2.60421286]
# Test custom metric:  [0.67520813 0.83069273 0.31554242 0.78226381 2.6037071 ]
# Train precision:  0.6318551
# Test precision:  0.27913198
# Creating recommendation profiles
# Train custom metric:  [0.68789221 0.81455954 0.31428091 0.77252241 2.58925508]
# Test custom metric:  [0.67997778 0.81350869 0.31389895 0.77999802 2.58738345]
# Train precision:  0.632776
# Test precision:  0.2793985
# Creating recommendation profiles
# Train custom metric:  [0.68465416 0.83684839 0.31574171 0.77748434 2.6147286 ]
# Test custom metric:  [0.67709724 0.83574261 0.31560971 0.78553475 2.61398431]
# Train precision:  0.63361394
# Test precision:  0.28080425
# Creating recommendation profiles
# Train custom metric:  [0.6816933  0.827036   0.31535424 0.77829368 2.60237721]
# Test custom metric:  [0.67282299 0.82663184 0.31535474 0.7858478  2.60065736]
# Train precision:  0.6340098
# Test precision:  0.2791111
# Creating recommendation profiles
# Train custom metric:  [0.6946334  0.83001662 0.31715684 0.77919437 2.62100122]
# Test custom metric:  [0.6885056  0.82990765 0.31697766 0.78719532 2.62258624]
# Train precision:  0.63493246
# Test precision:  0.2794377
# Creating recommendation profiles
# Train custom metric:  [0.69981032 0.83265959 0.31928992 0.77914924 2.63090907]
# Test custom metric:  [0.69082988 0.83146672 0.31898564 0.78661153 2.62789377]
# Train precision:  0.6347568
# Test precision:  0.2797042
# Creating recommendation profiles
# Train custom metric:  [0.68651306 0.84690476 0.31830768 0.77657948 2.62830498]
# Test custom metric:  [0.67835972 0.84644867 0.31804454 0.78437795 2.62723088]
# Train precision:  0.63507193
# Test precision:  0.28053513
# Creating recommendation profiles
# Train custom metric:  [0.68915583 0.82763804 0.31618835 0.77440642 2.60738864]
# Test custom metric:  [0.68106079 0.8268569  0.31588704 0.78254141 2.60634615]
# Train precision:  0.6348478
# Test precision:  0.27984533
# Creating recommendation profiles
# Train custom metric:  [0.65803806 0.79964073 0.31262516 0.77552321 2.54582717]
# Test custom metric:  [0.64932112 0.79932638 0.31227887 0.7837014  2.54462777]
# Train precision:  0.6323841
# Test precision:  0.2798871
# Creating recommendation profiles
# Train custom metric:  [0.67509027 0.83551188 0.31574642 0.77819801 2.60454657]
# Test custom metric:  [0.66720135 0.83451447 0.31580378 0.7862243  2.6037439 ]
# Train precision:  0.636156
# Test precision:  0.27968857
# Creating recommendation profiles
# Train custom metric:  [0.70311624 0.83848702 0.32150586 0.77271411 2.63582323]
# Test custom metric:  [0.69435078 0.83852658 0.32151001 0.78054394 2.6349313 ]
# Train precision:  0.63820964
# Test precision:  0.27906668
# Creating recommendation profiles
# Train custom metric:  [0.6904735  0.81902793 0.31574115 0.77736472 2.6026073 ]
# Test custom metric:  [0.68217703 0.81704884 0.31583604 0.78448067 2.59954258]
# Train precision:  0.637436
# Test precision:  0.2787845
# Creating recommendation profiles
# Train custom metric:  [0.70711007 0.83248782 0.3174901  0.775342   2.63242999]
# Test custom metric:  [0.69904591 0.83092057 0.31719088 0.78349584 2.63065321]
# Train precision:  0.6402312
# Test precision:  0.27897784
# Creating recommendation profiles
# Train custom metric:  [0.67871409 0.83942828 0.31655978 0.77269433 2.60739649]
# Test custom metric:  [0.67168744 0.83903783 0.31635215 0.78059432 2.60767174]
# Train precision:  0.637588
# Test precision:  0.27922085
# Creating recommendation profiles
# Train custom metric:  [0.70732666 0.83933679 0.31827474 0.77026707 2.63520525]
# Test custom metric:  [0.69874424 0.83826749 0.31806476 0.7779459  2.63302239]
# Train precision:  0.6385984
# Test precision:  0.2807651
# Creating recommendation profiles
# Train custom metric:  [0.70038757 0.84229397 0.31841871 0.77326579 2.63436603]
# Test custom metric:  [0.69195483 0.84233574 0.31811392 0.78114781 2.63355229]
# Train precision:  0.63875604
# Test precision:  0.27910066
# Creating recommendation profiles
# Train custom metric:  [0.69707444 0.82532734 0.32286592 0.77465379 2.61992149]
# Test custom metric:  [0.68880309 0.82455455 0.32255656 0.78271092 2.61862512]
# Train precision:  0.63855535
# Test precision:  0.2793776
# Creating recommendation profiles
# Train custom metric:  [0.70278469 0.83566032 0.31802782 0.77058153 2.62705435]
# Test custom metric:  [0.69431668 0.83465338 0.31797614 0.778277   2.6252232 ]
# Train precision:  0.6385821
# Test precision:  0.27938804
# Creating recommendation profiles
# Train custom metric:  [0.70908438 0.85177141 0.31859749 0.77595676 2.65541004]
# Test custom metric:  [0.70019222 0.85006926 0.31834323 0.78312158 2.65172628]
# Train precision:  0.64073056
# Test precision:  0.27859375
# Creating recommendation profiles
# Train custom metric:  [0.69878088 0.8283561  0.3180673  0.77086703 2.61607131]
# Test custom metric:  [0.68903823 0.82800981 0.31782436 0.77836811 2.6132405 ]
# Train precision:  0.6408199
# Test precision:  0.27885503
# Creating recommendation profiles
# Train custom metric:  [0.67715356 0.82098413 0.31970112 0.77598909 2.5938279 ]
# Test custom metric:  [0.66949802 0.82099307 0.31935575 0.78380479 2.59365162]
# Train precision:  0.63742656
# Test precision:  0.2790693
# Creating recommendation profiles
# Train custom metric:  [0.70978867 0.83601433 0.32339263 0.77137611 2.64057174]
# Test custom metric:  [0.70123082 0.83532686 0.32308586 0.77940402 2.63904756]
# Train precision:  0.64147526
# Test precision:  0.28001776
# Creating recommendation profiles
# Train custom metric:  [0.70390354 0.81079283 0.32150032 0.77030797 2.60650466]
# Test custom metric:  [0.69507645 0.81059226 0.3215839  0.77825691 2.60550951]
# Train precision:  0.640968
# Test precision:  0.28083563
# Creating recommendation profiles
# Train custom metric:  [0.68553494 0.83189111 0.31706089 0.77580566 2.6102926 ]
# Test custom metric:  [0.67770712 0.83212276 0.31699715 0.78359384 2.61042087]
# Train precision:  0.64109594
# Test precision:  0.27910063
# Creating recommendation profiles
# Train custom metric:  [0.68906538 0.81374725 0.31806304 0.77111695 2.59199262]
# Test custom metric:  [0.6796505  0.81311953 0.31766508 0.77851401 2.58894912]
# Train precision:  0.64130515
# Test precision:  0.2798009
# Creating recommendation profiles
# Train custom metric:  [0.68417905 0.83740513 0.31534428 0.77635031 2.61327878]
# Test custom metric:  [0.67608242 0.83743304 0.31545735 0.78393682 2.61290963]
# Train precision:  0.64058393
# Test precision:  0.2798087
# Creating recommendation profiles
# Train custom metric:  [0.69719556 0.80813152 0.31658515 0.77214433 2.59405656]
# Test custom metric:  [0.68846333 0.80734258 0.31643217 0.77932832 2.5915664 ]
# Train precision:  0.6440345
# Test precision:  0.27998903
# Creating recommendation profiles
# Train custom metric:  [0.69153892 0.84070167 0.32160179 0.77279559 2.62663796]
# Test custom metric:  [0.68282332 0.84039892 0.32131194 0.77961941 2.62415359]
# Train precision:  0.64344037
# Test precision:  0.27781248
# Creating recommendation profiles
# Train custom metric:  [0.70611982 0.81826861 0.318503   0.77215756 2.61504899]
# Test custom metric:  [0.69724905 0.81883664 0.31823542 0.77925484 2.61357595]
# Train precision:  0.64219564
# Test precision:  0.27992898
# Creating recommendation profiles
# Train custom metric:  [0.67789797 0.81511832 0.31790515 0.77686227 2.5877837 ]
# Test custom metric:  [0.6699698  0.81466397 0.31790986 0.78410396 2.58664759]
# Train precision:  0.6410183
# Test precision:  0.27920255
# Creating recommendation profiles
# Train custom metric:  [0.69588649 0.81683072 0.32122817 0.76978097 2.60372635]
# Test custom metric:  [0.68756253 0.81675765 0.3209536  0.77678673 2.60206051]
# Train precision:  0.6430875
# Test precision:  0.28025034
# Creating recommendation profiles
# Train custom metric:  [0.67852309 0.81546679 0.32221905 0.77574466 2.59195359]
# Test custom metric:  [0.66968246 0.81462894 0.32165219 0.78261885 2.58858244]
# Train precision:  0.6434153
# Test precision:  0.2781182
# Creating recommendation profiles
# Train custom metric:  [0.70211576 0.81791241 0.31936477 0.77976287 2.61915581]
# Test custom metric:  [0.69302799 0.81676097 0.31882467 0.78667768 2.61529132]
# Train precision:  0.6448238
# Test precision:  0.27918163
# Creating recommendation profiles
# Train custom metric:  [0.67344789 0.80990898 0.31874471 0.77213638 2.57423796]
# Test custom metric:  [0.66590847 0.80977555 0.31837003 0.78026737 2.57432142]
# Train precision:  0.64339566
# Test precision:  0.27851534
# Creating recommendation profiles
# Train custom metric:  [0.68440723 0.82097133 0.316567   0.77900689 2.60095245]
# Test custom metric:  [0.67572427 0.82088324 0.31629566 0.78593091 2.59883408]
# Train precision:  0.643496
# Test precision:  0.27883676
# Creating recommendation profiles
# Train custom metric:  [0.70646601 0.81381308 0.31995941 0.77374113 2.61397964]
# Test custom metric:  [0.69850963 0.81259363 0.31957103 0.78120297 2.61187726]
# Train precision:  0.64719504
# Test precision:  0.27868518
# Creating recommendation profiles
# Train custom metric:  [0.68657139 0.80971073 0.31869015 0.77118251 2.58615478]
# Test custom metric:  [0.67881846 0.80887871 0.31845937 0.77819089 2.58434742]
# Train precision:  0.6460412
# Test precision:  0.2785598
# Creating recommendation profiles
# Train custom metric:  [0.68752303 0.82399285 0.3202903  0.7739307  2.60573687]
# Test custom metric:  [0.6787776  0.8232148  0.31983801 0.78099847 2.60282888]
# Train precision:  0.6452315
# Test precision:  0.2786643
# Creating recommendation profiles
# Train custom metric:  [0.70155838 0.83012778 0.32278003 0.77430523 2.62877141]
# Test custom metric:  [0.69382792 0.82966841 0.32194596 0.781796   2.62723829]
# Train precision:  0.64701945
# Test precision:  0.2785493
# Creating recommendation profiles
# Train custom metric:  [0.68046264 0.84679971 0.31849045 0.77590942 2.62166222]
# Test custom metric:  [0.67218666 0.84623992 0.31818337 0.7832029  2.61981285]
# Train precision:  0.6470068
# Test precision:  0.2790824
# Creating recommendation profiles
# Train custom metric:  [0.68400393 0.83747737 0.32074646 0.77419279 2.61642054]
# Test custom metric:  [0.67632407 0.83696264 0.32026421 0.78160568 2.6151566 ]
# Train precision:  0.64702415
# Test precision:  0.27762175
# Creating recommendation profiles
# Train custom metric:  [0.68998945 0.81008749 0.32091893 0.77435398 2.59534985]
# Test custom metric:  [0.68116793 0.80982738 0.32036263 0.78160573 2.59296367]
# Train precision:  0.6468383
# Test precision:  0.27662882
# Creating recommendation profiles
# Train custom metric:  [0.69572681 0.83549981 0.32240232 0.77786703 2.63149597]
# Test custom metric:  [0.68647081 0.83449541 0.3221082  0.78497816 2.62805258]
# Train precision:  0.6470641
# Test precision:  0.27735257
# Creating recommendation profiles
# Train custom metric:  [0.66900625 0.82760666 0.31764899 0.77614115 2.59040304]
# Test custom metric:  [0.66096937 0.82722126 0.31722553 0.78361323 2.58902939]
# Train precision:  0.64708287
# Test precision:  0.27905884
# Creating recommendation profiles
# Train custom metric:  [0.68754628 0.81271399 0.31923884 0.77664071 2.59613982]
# Test custom metric:  [0.67937775 0.81239127 0.31875907 0.78374405 2.59427213]
# Train precision:  0.64774054
# Test precision:  0.27788043
# Creating recommendation profiles
# Train custom metric:  [0.69319348 0.81137083 0.32013012 0.775393   2.60008742]
# Test custom metric:  [0.68444476 0.81100699 0.31943662 0.78195733 2.5968457 ]
# Train precision:  0.6472687
# Test precision:  0.27905363
# Creating recommendation profiles
# Train custom metric:  [0.71495684 0.82495614 0.32259859 0.77401961 2.63653118]
# Test custom metric:  [0.70526311 0.82411043 0.32177444 0.78142174 2.63256973]
# Train precision:  0.6500992
# Test precision:  0.276297
# Creating recommendation profiles
# Train custom metric:  [0.71251919 0.83325667 0.32366579 0.76685117 2.63629282]
# Test custom metric:  [0.70475315 0.8333366  0.32342757 0.77416894 2.63568626]
# Train precision:  0.6490661
# Test precision:  0.278356
# Creating recommendation profiles
# Train custom metric:  [0.68509007 0.82371778 0.3214853  0.77116133 2.60145448]
# Test custom metric:  [0.67645377 0.82363656 0.32069897 0.77890769 2.59969699]
# Train precision:  0.64979106
# Test precision:  0.27832982
# Creating recommendation profiles
# Train custom metric:  [0.70209133 0.81420819 0.31750425 0.77132459 2.60512835]
# Test custom metric:  [0.69404651 0.8138838  0.31745351 0.77854448 2.6039283 ]
# Train precision:  0.6481646
# Test precision:  0.2791111
# Creating recommendation profiles
# Train custom metric:  [0.6862229  0.84162137 0.32258159 0.77439801 2.62482386]
# Test custom metric:  [0.67789698 0.84130286 0.32208962 0.78257024 2.62385969]
# Train precision:  0.64840925
# Test precision:  0.2780398
# Creating recommendation profiles
# Train custom metric:  [0.68950007 0.81924681 0.31841883 0.77185564 2.59902135]
# Test custom metric:  [0.68111364 0.81896335 0.31809731 0.77943578 2.59761008]
# Train precision:  0.64971894
# Test precision:  0.27841347
# Creating recommendation profiles
# Train custom metric:  [0.67320621 0.82027192 0.32414545 0.77426341 2.59188699]
# Test custom metric:  [0.66576392 0.82035163 0.32353461 0.78179859 2.59144875]
# Train precision:  0.64927065
# Test precision:  0.27741534
# Creating recommendation profiles
# Train custom metric:  [0.7180502  0.83880404 0.31954659 0.77361992 2.65002074]
# Test custom metric:  [0.70978026 0.83814864 0.31919522 0.78165625 2.64878037]
# Train precision:  0.6508892
# Test precision:  0.27855718
# Creating recommendation profiles
# Train custom metric:  [0.69547799 0.82636474 0.32298773 0.77126273 2.61609319]
# Test custom metric:  [0.68774683 0.82516485 0.32260871 0.77825462 2.61377501]
# Train precision:  0.6512177
# Test precision:  0.27841607
# Creating recommendation profiles
# Train custom metric:  [0.71396406 0.81048058 0.32109559 0.77119771 2.61673793]
# Test custom metric:  [0.70518832 0.8097346  0.32058775 0.77828552 2.6137962 ]
# Train precision:  0.6524217
# Test precision:  0.27793527
# Creating recommendation profiles
# Train custom metric:  [0.70868947 0.84263213 0.32469964 0.77132558 2.64734682]
# Test custom metric:  [0.70140929 0.8425336  0.32443599 0.77870017 2.64707905]
# Train precision:  0.65216935
# Test precision:  0.27766094
# Creating recommendation profiles
# Train custom metric:  [0.70810883 0.82410364 0.31916821 0.77545151 2.62683218]
# Test custom metric:  [0.69976712 0.82365818 0.31888771 0.78299658 2.6253096 ]
# Train precision:  0.6525196
# Test precision:  0.27647728
# Creating recommendation profiles
# Train custom metric:  [0.69487316 0.82480545 0.32313072 0.77861504 2.62142437]
# Test custom metric:  [0.68488165 0.82383066 0.32215234 0.78500142 2.61586607]
# Train precision:  0.6508713
# Test precision:  0.27778897
# Creating recommendation profiles
# Train custom metric:  [0.68570893 0.82287288 0.32131003 0.7746131  2.60450494]
# Test custom metric:  [0.67625435 0.82238883 0.32045508 0.78197923 2.60107749]
# Train precision:  0.65184075
# Test precision:  0.27948475
# Creating recommendation profiles
# Train custom metric:  [0.67697912 0.80100697 0.32031671 0.77208282 2.57038562]
# Test custom metric:  [0.66921766 0.80037966 0.31970063 0.7794179  2.56871585]
# Train precision:  0.65073496
# Test precision:  0.27640936
# Creating recommendation profiles
# Train custom metric:  [0.6664464  0.8236071  0.31783026 0.77309097 2.58097473]
# Test custom metric:  [0.65839157 0.82356254 0.31722312 0.78065692 2.57983415]
# Train precision:  0.65001845
# Test precision:  0.2779588
# Creating recommendation profiles
# Train custom metric:  [0.68272745 0.83077407 0.32015904 0.77770085 2.61136141]
# Test custom metric:  [0.67389454 0.82908975 0.3198925  0.7845861  2.60746288]
# Train precision:  0.65061337
# Test precision:  0.27820438
# Creating recommendation profiles
# Train custom metric:  [0.69752116 0.81716974 0.31858709 0.76807705 2.60135504]
# Test custom metric:  [0.68934782 0.81721606 0.31832754 0.77633471 2.60122614]
# Train precision:  0.65232694
# Test precision:  0.27922344
# Creating recommendation profiles
# Train custom metric:  [0.69672387 0.80795486 0.31779898 0.7750874  2.5975651 ]
# Test custom metric:  [0.68846325 0.80729477 0.31752835 0.78304449 2.59633085]
# Train precision:  0.65250957
# Test precision:  0.27778375
# Creating recommendation profiles
# Train custom metric:  [0.68567638 0.80976169 0.31987797 0.77967993 2.59499596]
# Test custom metric:  [0.67602395 0.80888039 0.31928457 0.78681852 2.59100742]
# Train precision:  0.6527548
# Test precision:  0.27711743
# Creating recommendation profiles
# Train custom metric:  [0.69963571 0.81634337 0.31968942 0.77110075 2.60676925]
# Test custom metric:  [0.69087251 0.8160727  0.31902358 0.77893123 2.60490001]
# Train precision:  0.65321344
# Test precision:  0.27800843
# Creating recommendation profiles
# Train custom metric:  [0.68531405 0.82174933 0.32531332 0.77578562 2.60816233]
# Test custom metric:  [0.67655788 0.82228515 0.32478684 0.78270655 2.60633642]
# Train precision:  0.6542365
# Test precision:  0.27906147
# Creating recommendation profiles
# Train custom metric:  [0.68205532 0.83016067 0.31988548 0.77679138 2.60889285]
# Test custom metric:  [0.67386587 0.82914901 0.31925423 0.78403966 2.60630877]
# Train precision:  0.6553072
# Test precision:  0.27748063
# Creating recommendation profiles
# Train custom metric:  [0.6795793  0.80644368 0.32154084 0.77072079 2.57828461]
# Test custom metric:  [0.67016392 0.80614189 0.32085246 0.77824583 2.57540409]
# Train precision:  0.65222967
# Test precision:  0.2781626
# Creating recommendation profiles
# Train custom metric:  [0.67344134 0.81592887 0.3168158  0.77557996 2.58176597]
# Test custom metric:  [0.66455916 0.81486652 0.31647069 0.78337371 2.57927007]
# Train precision:  0.6555445
# Test precision:  0.27796143
# Creating recommendation profiles
# Train custom metric:  [0.70501917 0.81425325 0.3177915  0.77427559 2.61133952]
# Test custom metric:  [0.69585822 0.81373689 0.31744789 0.781393   2.608436  ]
# Train precision:  0.65543574
# Test precision:  0.27731603
# Creating recommendation profiles
# Train custom metric:  [0.68753312 0.805089   0.32403032 0.77114285 2.58779528]
# Test custom metric:  [0.67988492 0.80591851 0.32349673 0.77770625 2.5870064 ]
# Train precision:  0.654745
# Test precision:  0.27834553
# Creating recommendation profiles
# Train custom metric:  [0.66663646 0.8410753  0.32181411 0.77591255 2.60543841]
# Test custom metric:  [0.65817924 0.84164343 0.32140929 0.78311286 2.60434482]
# Train precision:  0.65326595
# Test precision:  0.2772246
# Creating recommendation profiles
# Train custom metric:  [0.71505551 0.82906043 0.32233045 0.77087658 2.63732297]
# Test custom metric:  [0.70537066 0.82893014 0.32193446 0.77781572 2.63405099]
# Train precision:  0.6569603
# Test precision:  0.27888116
# Creating recommendation profiles
# Train custom metric:  [0.66702058 0.82172859 0.32421473 0.77457462 2.58753853]
# Test custom metric:  [0.65889669 0.8216445  0.32397361 0.7815859  2.58610071]
# Train precision:  0.65349954
# Test precision:  0.2775146
# Creating recommendation profiles
# Train custom metric:  [0.67773251 0.82173023 0.31595829 0.77517806 2.5905991 ]
# Test custom metric:  [0.6693982  0.8211871  0.31569056 0.78246742 2.58874327]
# Train precision:  0.6555909
# Test precision:  0.27676994
# Creating recommendation profiles
# Train custom metric:  [0.70354862 0.80099697 0.32336989 0.77411281 2.60202829]
# Test custom metric:  [0.69438073 0.80053569 0.32253248 0.78072458 2.59817349]
# Train precision:  0.6561991
# Test precision:  0.2776766
# Creating recommendation profiles
# Train custom metric:  [0.69960375 0.84849136 0.32342183 0.77250511 2.64402206]
# Test custom metric:  [0.69082286 0.84766435 0.32251673 0.78003693 2.64104087]
# Train precision:  0.65743834
# Test precision:  0.276216

# %%
print(best_value)
print(best_epoch)
# Out:
# 0.28110474
# 68

# %%
print(best_metric_value)
print(best_metric_epoch)
# Out:
# 2.653793045789702
# 64

# %%
for i in range(5):
    plt.figure()
    plt.plot(2*np.arange(150), np.array(train_metrics_vals)[:, i], label='Train')
    plt.plot(2*np.arange(150), np.array(test_metrics_vals)[:, i], label='Test')
    plt.xlabel("Epoch", fontsize=14)
    plt.ylabel("Value", fontsize=14)
    plt.legend(prop={'size': 12})

# %%
plt.figure()
plt.plot(2*np.arange(150), np.array(train_precision_vals), label='Train')
plt.plot(2*np.arange(150), np.array(precision_vals), label='Test')
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.legend(prop={'size': 12})
